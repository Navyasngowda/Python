# %%
import pandas as pd
first=pd.read_csv("student.csv")
first
# Out:
#      Slno            Name  Class  Address             Mobile
# 0       1          barjraj   MBA  Madikeri      0345 42 0274
# 1       2     ramdin verma   MBA       NaN  095086-173-31-37
# 2       3  sharat chandran   MBA  Madikeri  057843 018 15-85
# 3       4  birender mandal   MCA  Madikeri      0698-1368378
# 4       5             amit   MCA  Madikeri     007 916 73 79
# ..    ...              ...   ...       ...               ...
# 194   195      mohd shahid   MBA     Delhi  048360-487 06-60
# 195   196        ramvilash   MBA     Delhi      080-965 2067
# 196   197          kuldeep   MCA     Delhi     0973 05 08-19
# 197   198          kuldeep   MBA     Delhi          040164 1
# 198   199     nanku prasad   MBA     Delhi     01462 08-6859
#
# [199 rows x 5 columns]

# %%
first.iloc[10]
first.loc[10:20:2]
# Out:
#     Slno         Name  Class   Address           Mobile
# 10    11          abhi   MCA        NaN    0027360 8 81
# 12    13  khadak singh   MBA     Mysore    084-657-28 7
# 14    15    chanderpal   MBA        NaN     01780 47 57
# 16    17        rajeev   MCA  Bangalore             NaN
# 18    19       durgesh   MBA  Bangalore  096182-69291 0
# 20    21     ram kumar   MBA  Bangalore             NaN

# %%
first.loc[0][1]
# Out:
# 'barjraj'

# %%
first.loc[0]['Slno']
# Out:
# 1

# %%
first.loc[3,'Address ']="kalladka"

# %%
first
# Out:
#      Slno            Name  Class  Address             Mobile Address
# 0       1          barjraj   MBA  Madikeri      0345 42 0274  kerala
# 1       2     ramdin verma   MBA       NaN  095086-173-31-37     NaN
# 2       3  sharat chandran   MBA  Madikeri  057843 018 15-85     NaN
# 3       4  birender mandal   MCA  kalladka      0698-1368378  kerala
# 4       5             amit   MCA  Madikeri     007 916 73 79     NaN
# ..    ...              ...   ...       ...               ...     ...
# 194   195      mohd shahid   MBA     Delhi  048360-487 06-60     NaN
# 195   196        ramvilash   MBA     Delhi      080-965 2067     NaN
# 196   197          kuldeep   MCA     Delhi     0973 05 08-19     NaN
# 197   198          kuldeep   MBA     Delhi          040164 1     NaN
# 198   199     nanku prasad   MBA     Delhi     01462 08-6859     NaN
#
# [199 rows x 6 columns]

# %%
third=pd.read_excel("student.xlsx")

# %%
third.head()
# Out:
#    Slno            Name  Class  Address             Mobile
# 0     1          barjraj   MBA  Madikeri      0345 42 0274
# 1     2     ramdin verma   MBA       NaN  095086-173-31-37
# 2     3  sharat chandran   MBA  Madikeri  057843 018 15-85
# 3     4  birender mandal   MCA  Madikeri      0698-1368378
# 4     5             amit   MCA  Madikeri     007 916 73 79

# %%
type(third)
# Out:
# pandas.core.frame.DataFrame

# %%
type(third['Slno'])
# Out:
# pandas.core.series.Series

# %%
type(first)
# Out:
# pandas.core.frame.DataFrame

# %%
third.loc[197,'Name ']="Navya"
third
# Out:
#      Slno            Name  Class  Address             Mobile      Name
# 0       1          barjraj   MBA  Madikeri      0345 42 0274       NaN
# 1       2     ramdin verma   MBA       NaN  095086-173-31-37       NaN
# 2       3  sharat chandran   MBA  Madikeri  057843 018 15-85       NaN
# 3       4  birender mandal   MCA  Madikeri      0698-1368378       NaN
# 4       5             amit   MCA  Madikeri     007 916 73 79       NaN
# ..    ...              ...   ...       ...               ...       ...
# 194   195      mohd shahid   MBA     Delhi  048360-487 06-60       NaN
# 195   196        ramvilash   MBA     Delhi      080-965 2067       NaN
# 196   197          kuldeep   MCA     Delhi     0973 05 08-19       NaN
# 197   198            Navya   MBA     Delhi          040164 1     Navya
# 198   199     nanku prasad   MBA     Delhi     01462 08-6859  charitra
#
# [199 rows x 6 columns]

# %%
third.loc[198,'Name']="charitra"
third
# Out:
#      Slno            Name  Class  Address             Mobile      Name
# 0       1          barjraj   MBA  Madikeri      0345 42 0274       NaN
# 1       2     ramdin verma   MBA       NaN  095086-173-31-37       NaN
# 2       3  sharat chandran   MBA  Madikeri  057843 018 15-85       NaN
# 3       4  birender mandal   MCA  Madikeri      0698-1368378       NaN
# 4       5             amit   MCA  Madikeri     007 916 73 79       NaN
# ..    ...              ...   ...       ...               ...       ...
# 194   195      mohd shahid   MBA     Delhi  048360-487 06-60       NaN
# 195   196        ramvilash   MBA     Delhi      080-965 2067       NaN
# 196   197          kuldeep   MCA     Delhi     0973 05 08-19       NaN
# 197   198            Navya   MBA     Delhi          040164 1     Navya
# 198   199     nanku prasad   MBA     Delhi     01462 08-6859  charitra
#
# [199 rows x 6 columns]

# %%
third.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Slno      199 non-null    int64
#  1   Name      199 non-null    object
#  2   Class     199 non-null    object
#  3   Address   184 non-null    object
#  4   Mobile    184 non-null    object
#  5   Name      2 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 9.5+ KB

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
first.head(60) #max.no.of records to display
# Out:
#     Slno                 Name  Class   Address             Mobile Address
# 0      1               barjraj   MBA   Madikeri      0345 42 0274  kerala
# 1      2          ramdin verma   MBA        NaN  095086-173-31-37     NaN
# 2      3       sharat chandran   MBA   Madikeri  057843 018 15-85     NaN
# 3      4       birender mandal   MCA   Madikeri      0698-1368378  kerala
# 4      5                  amit   MCA   Madikeri     007 916 73 79     NaN
# 5      6                kushal   MBA        NaN     00576329-0345     NaN
# 6      7                 kasid   MBA     Mysore      0125-901-279     NaN
# 7      8                barjaj   MCA     Mysore               NaN     NaN
# 8      9          vikram singh   MCA     Mysore   03709-765-28-42     NaN
# 9     10                mayank   MBA     Mysore       01725 30 75     NaN
# 10    11                  abhi   MCA        NaN      0027360 8 81     NaN
# 11    12        ram dutt gupta   MBA     Mysore               NaN     NaN
# ...

# %%
pd.options.display.max_rows=100

# %%
first.head(100)
# Out:
#     Slno                   Name  Class   Address             Mobile Address
# 0      1                 barjraj   MBA   Madikeri      0345 42 0274  kerala
# 1      2            ramdin verma   MBA        NaN  095086-173-31-37     NaN
# 2      3         sharat chandran   MBA   Madikeri  057843 018 15-85     NaN
# 3      4         birender mandal   MCA   Madikeri      0698-1368378  kerala
# 4      5                    amit   MCA   Madikeri     007 916 73 79     NaN
# 5      6                  kushal   MBA        NaN     00576329-0345     NaN
# 6      7                   kasid   MBA     Mysore      0125-901-279     NaN
# 7      8                  barjaj   MCA     Mysore               NaN     NaN
# 8      9            vikram singh   MCA     Mysore   03709-765-28-42     NaN
# 9     10                  mayank   MBA     Mysore       01725 30 75     NaN
# 10    11                    abhi   MCA        NaN      0027360 8 81     NaN
# ...

# %%
FinalIDF=pd.concat([first,third]) #if 2table's col.name are same,valuue will be added otherwise new column will created
FinalIDF.tail(10)
# Out:
#      Slno          Name  Class Address             Mobile Address      Name
# 189   190  kuldeep singh   MCA    Delhi      0914603 4 48     NaN       NaN
# 190   191         murari   MBA    Delhi       097 7832-14     NaN       NaN
# 191   192      ramvilash   MBA    Delhi    01680-085 3802     NaN       NaN
# 192   193           abhi   MBA    Delhi               NaN     NaN       NaN
# 193   194  vishal @ moni   MBA      NaN     0498 567-4079     NaN       NaN
# 194   195    mohd shahid   MBA    Delhi  048360-487 06-60     NaN       NaN
# 195   196      ramvilash   MBA    Delhi      080-965 2067     NaN       NaN
# 196   197        kuldeep   MCA    Delhi     0973 05 08-19     NaN       NaN
# 197   198          Navya   MBA    Delhi          040164 1     NaN     Navya
# 198   199   nanku prasad   MBA    Delhi     01462 08-6859     NaN  charitra

# %%
#data cleaning
#*empty cells
#*data in wrong format
#*wrong data
#*duplicates

# %%
cfirst=first.dropna()
cfirst
# Out:
#    Slno            Name  Class  Address         Mobile Address
# 0     1          barjraj   MBA  Madikeri  0345 42 0274  kerala
# 3     4  birender mandal   MCA  kalladka  0698-1368378  kerala

# %%
first.dropna(inplace=True) #true affecdts original database
first
# Out:
#    Slno            Name  Class  Address         Mobile Address
# 0     1          barjraj   MBA  Madikeri  0345 42 0274  kerala
# 3     4  birender mandal   MCA  kalladka  0698-1368378  kerala

# %%
first.head(10)
first
# Out:
#    Slno            Name  Class  Address         Mobile Address
# 0     1          barjraj   MBA  Madikeri  0345 42 0274  kerala
# 3     4  birender mandal   MCA  kalladka  0698-1368378  kerala

# %%
third.fillna("NOT AVAILABLE",inplace=True)
third.head(10)
# Out:
#    Slno            Name  Class       Address             Mobile           Name
# 0     1          barjraj   MBA       Madikeri      0345 42 0274  NOT AVAILABLE
# 1     2     ramdin verma   MBA  NOT AVAILABLE  095086-173-31-37  NOT AVAILABLE
# 2     3  sharat chandran   MBA       Madikeri  057843 018 15-85  NOT AVAILABLE
# 3     4  birender mandal   MCA       Madikeri      0698-1368378  NOT AVAILABLE
# 4     5             amit   MCA       Madikeri     007 916 73 79  NOT AVAILABLE
# 5     6           kushal   MBA  NOT AVAILABLE     00576329-0345  NOT AVAILABLE
# 6     7            kasid   MBA         Mysore      0125-901-279  NOT AVAILABLE
# 7     8           barjaj   MCA         Mysore     NOT AVAILABLE  NOT AVAILABLE
# 8     9     vikram singh   MCA         Mysore   03709-765-28-42  NOT AVAILABLE
# 9    10           mayank   MBA         Mysore       01725 30 75  NOT AVAILABLE

# %%
x=third["Slno"].mean()
third["Slno"].fillna(x,inplace=True)
third
# Out:
#      Slno            Name  Class       Address             Mobile  \
# 0       1          barjraj   MBA       Madikeri      0345 42 0274
# 1       2     ramdin verma   MBA  NOT AVAILABLE  095086-173-31-37
# 2       3  sharat chandran   MBA       Madikeri  057843 018 15-85
# 3       4  birender mandal   MCA       Madikeri      0698-1368378
# 4       5             amit   MCA       Madikeri     007 916 73 79
# ..    ...              ...   ...            ...               ...
# 194   195      mohd shahid   MBA          Delhi  048360-487 06-60
# 195   196        ramvilash   MBA          Delhi      080-965 2067
# 196   197          kuldeep   MCA          Delhi     0973 05 08-19
# 197   198            Navya   MBA          Delhi          040164 1
# 198   199     nanku prasad   MBA          Delhi     01462 08-6859
#
#               Name
# 0    NOT AVAILABLE
# 1    NOT AVAILABLE
# 2    NOT AVAILABLE
# 3    NOT AVAILABLE
# 4    NOT AVAILABLE
# ..             ...
# 194  NOT AVAILABLE
# ...

# %%
third.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# Length: 199, dtype: bool

# %%
#select specific column
t=third[['Name ','Address ']]
t
# Out:
#                Name        Address
# 0            barjraj       Madikeri
# 1       ramdin verma  NOT AVAILABLE
# 2    sharat chandran       Madikeri
# 3    birender mandal       Madikeri
# 4               amit       Madikeri
# ..               ...            ...
# 194      mohd shahid          Delhi
# 195        ramvilash          Delhi
# 196          kuldeep          Delhi
# 197            Navya          Delhi
# 198     nanku prasad          Delhi
#
# [199 rows x 2 columns]

# %%
third.loc[:,["Name" ,"Mobile"]]
third
# Out:
#      Slno            Name  Class       Address             Mobile  \
# 0       1          barjraj   MBA       Madikeri      0345 42 0274
# 1       2     ramdin verma   MBA  NOT AVAILABLE  095086-173-31-37
# 2       3  sharat chandran   MBA       Madikeri  057843 018 15-85
# 3       4  birender mandal   MCA       Madikeri      0698-1368378
# 4       5             amit   MCA       Madikeri     007 916 73 79
# ..    ...              ...   ...            ...               ...
# 194   195      mohd shahid   MBA          Delhi  048360-487 06-60
# 195   196        ramvilash   MBA          Delhi      080-965 2067
# 196   197          kuldeep   MCA          Delhi     0973 05 08-19
# 197   198            Navya   MBA          Delhi          040164 1
# 198   199     nanku prasad   MBA          Delhi     01462 08-6859
#
#               Name
# 0    NOT AVAILABLE
# 1    NOT AVAILABLE
# 2    NOT AVAILABLE
# 3    NOT AVAILABLE
# 4    NOT AVAILABLE
# ..             ...
# 194  NOT AVAILABLE
# ...
