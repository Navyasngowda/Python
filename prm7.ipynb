# %%
from matplotlib import pyplot
import numpy
i=5
a=numpy.random.randint(10,90,(4,5))
print(a)
# Out:
# [[41 59 81 48 69]
#  [83 80 84 51 44]
#  [66 19 61 14 36]
#  [33 31 48 42 19]]

# %%
a.shape
# Out:
# (4, 5)

# %%
a.reshape(5,4)
# Out:
# array([[41, 59, 81, 48],
#        [69, 83, 80, 84],
#        [51, 44, 66, 19],
#        [61, 14, 36, 33],
#        [31, 48, 42, 19]])

# %%
a.itemsize #to display individual item size in bytes
# Out:
# 8

# %%
a.dtype
# Out:
# dtype('int64')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(dpi=100)

# %%
plt.plot(a)
plt.title("line plot of numpy arrays")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
